# %%
from ultralytics import YOLO

# %%
# Define the data paths
data = {
    'train': 'D:/ARTIFICIAL INTELLIGENCE/SEMESTER 1/Computer Vision and Deep Learning/CV_PROJECT_LAZY_TRAIN/human-pose-estimation-opencv/Chair_occupancy/Training_chair_detection_Yolov8/dataset/images/train',
    'val': 'D:/ARTIFICIAL INTELLIGENCE/SEMESTER 1/Computer Vision and Deep Learning/CV_PROJECT_LAZY_TRAIN/human-pose-estimation-opencv/Chair_occupancy/Training_chair_detection_Yolov8/dataset/images/val',
    'names': ['chair']  # List of class names
}

# Save the data.yaml file
import yaml

# Save the data.yaml file
data_yaml = {
    'path': 'D:/ARTIFICIAL INTELLIGENCE/SEMESTER 1/Computer Vision and Deep Learning/CV_PROJECT_LAZY_TRAIN/human-pose-estimation-opencv/Chair_occupancy/Training_chair_detection_Yolov8/dataset',
    'train': 'images/train',
    'val': 'images/val',
    'names': {0: 'chair'}
}

with open('data.yaml', 'w') as outfile:
    yaml.dump(data_yaml, outfile, default_flow_style=False)

# %%
# Define the path to the YOLOv8 model
model = YOLO('yolov8n.pt')  # You can choose 'yolov8s.pt', 'yolov8m.pt', etc., depending on your requirements

# Train the model
results = model.train(data='data.yaml', epochs=30, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.196  Python-3.12.3 torch-2.3.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2060 with Max-Q Design, 6144MiB)
# ...
